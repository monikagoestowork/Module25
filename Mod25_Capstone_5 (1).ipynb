# %%
# This script focuses on the three core steps: importing the library, reading the file, and printing the head of the data, Data Cleaning and Preparation for Plotting 
# Create a scatter plot matrix (pair plot) to visualize relationships
# The 'hue' parameter colors the points based on the 'target' column ('healthy' vs 'diseased')

# %%
import pandas as pd
from sklearn.preprocessing import normalize
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans # Using KMeans as an example

# %%
# Define the file path to your dataset
file_path = r"C:\Users\monik\health_lifestyle_classification.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# %%
df.head(5)
# Out:
#    survey_code  age  gender      height     weight        bmi  bmi_estimated  \
# 0            1   56    Male  173.416872  56.886640  18.915925      18.915925
# 1            2   69  Female  163.207380  97.799859  36.716278      36.716278
# 2            3   46    Male  177.281966  80.687562  25.673050      25.673050
# 3            4   32  Female  172.101255  63.142868  21.318480      21.318480
# 4            5   60  Female  163.608816  40.000000  14.943302      14.943302
#
#    bmi_scaled  bmi_corrected  waist_size  ...  sunlight_exposure  \
# 0   56.747776      18.989117   72.165130  ...               High
# 1  110.148833      36.511417   85.598889  ...               High
# 2   77.019151      25.587429   90.295030  ...               High
# 3   63.955440      21.177109  100.504211  ...               High
# 4   44.829907      14.844299   69.021150  ...               High
#
#    meals_per_day  caffeine_intake  family_history  pet_owner  \
# ...

# %%
from sklearn.preprocessing import normalize
import pandas as pd

data = pd.read_csv(file_path)
# Keep only numeric columns and clean missing values
data = data.select_dtypes(include='number').dropna()

# Normalize the data
data_scaled = normalize(data)

# Convert back to DataFrame with original column names
data_scaled = pd.DataFrame(data_scaled, columns=data.columns)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer

# Define the file path to your dataset
file_path = r"C:\Users\monik\health_lifestyle_classification.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# --- Initial Data Inspection ---
print("First 5 rows of the dataset:")
print(df.head())

print("\nNull value counts before cleaning:")
print(df.isnull().sum())


# --- Data Cleaning and Preparation for Plotting ---

# Select the columns needed for the visualization
plot_columns = ['age', 'bmi', 'blood_pressure', 'calorie_intake', 'stress_level', 'target']
plot_df = df[plot_columns].copy()

# Identify numerical columns for imputation
numerical_cols = plot_df.select_dtypes(include=np.number).columns.tolist()

# Handle Missing Values using Imputation for the selected columns
# We use SimpleImputer to fill NaN values with the mean of their respective columns.
imputer = SimpleImputer(strategy='mean')

# Apply the imputer to the numerical columns of our plotting DataFrame
plot_df[numerical_cols] = imputer.fit_transform(plot_df[numerical_cols])

print("\nNull value counts after cleaning for plotting columns:")
print(plot_df.isnull().sum())


# --- Data Visualization ---

# Create a scatter plot matrix (pair plot) to visualize relationships
# The 'hue' parameter colors the points based on the 'target' column ('healthy' vs 'diseased')
print("\nGenerating scatter plot matrix...")
sns.pairplot(plot_df, hue='target', vars=['age', 'bmi', 'blood_pressure', 'calorie_intake', 'stress_level'])

# Add a title to the overall plot
plt.suptitle('Relationship between Health Factors and Target Outcome', y=1.02)

# Display the plot
plt.show()
# Out:
# First 5 rows of the dataset:
#    survey_code  age  gender      height     weight        bmi  bmi_estimated  \
# 0            1   56    Male  173.416872  56.886640  18.915925      18.915925
# 1            2   69  Female  163.207380  97.799859  36.716278      36.716278
# 2            3   46    Male  177.281966  80.687562  25.673050      25.673050
# 3            4   32  Female  172.101255  63.142868  21.318480      21.318480
# 4            5   60  Female  163.608816  40.000000  14.943302      14.943302
#
#    bmi_scaled  bmi_corrected  waist_size  ...  sunlight_exposure  \
# 0   56.747776      18.989117   72.165130  ...               High
# 1  110.148833      36.511417   85.598889  ...               High
# 2   77.019151      25.587429   90.295030  ...               High
# 3   63.955440      21.177109  100.504211  ...               High
# 4   44.829907      14.844299   69.021150  ...               High
#
#    meals_per_day  caffeine_intake  family_history  pet_owner  \
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer

# Define the file path to your dataset
file_path = r"C:\Users\monik\health_lifestyle_classification.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# --- Initial Data Inspection ---
print("First 5 rows of the dataset:")
print(df.head())

print("\nNull value counts before cleaning:")
print(df.isnull().sum())


# --- Data Cleaning and Preparation for Plotting ---

# Select the columns needed for the visualization
plot_columns = ['age', 'bmi', 'blood_pressure', 'calorie_intake', 'stress_level', 'target']
plot_df = df[plot_columns].copy()

# Identify numerical columns for imputation
numerical_cols = plot_df.select_dtypes(include=np.number).columns.tolist()

# Handle Missing Values using Imputation for the selected columns
# We use SimpleImputer to fill NaN values with the mean of their respective columns.
imputer = SimpleImputer(strategy='mean')

# Apply the imputer to the numerical columns of our plotting DataFrame
plot_df[numerical_cols] = imputer.fit_transform(plot_df[numerical_cols])

print("\nNull value counts after cleaning for plotting columns:")
print(plot_df.isnull().sum())


# --- Data Visualization ---

# Create a scatter plot matrix (pair plot) to visualize relationships
# The 'hue' parameter colors the points based on the 'target' column ('healthy' vs 'diseased')
print("\nGenerating scatter plot matrix...")
sns.pairplot(plot_df, hue='target', vars=['age', 'bmi', 'blood_pressure', 'calorie_intake', 'stress_level'])

# Add a title to the overall plot
plt.suptitle('Relationship between Health Factors and Target Outcome', y=1.02)

# Display the plot
plt.show()
# Out:
# First 5 rows of the dataset:
#    survey_code  age  gender      height     weight        bmi  bmi_estimated  \
# 0            1   56    Male  173.416872  56.886640  18.915925      18.915925
# 1            2   69  Female  163.207380  97.799859  36.716278      36.716278
# 2            3   46    Male  177.281966  80.687562  25.673050      25.673050
# 3            4   32  Female  172.101255  63.142868  21.318480      21.318480
# 4            5   60  Female  163.608816  40.000000  14.943302      14.943302
#
#    bmi_scaled  bmi_corrected  waist_size  ...  sunlight_exposure  \
# 0   56.747776      18.989117   72.165130  ...               High
# 1  110.148833      36.511417   85.598889  ...               High
# 2   77.019151      25.587429   90.295030  ...               High
# 3   63.955440      21.177109  100.504211  ...               High
# 4   44.829907      14.844299   69.021150  ...               High
#
#    meals_per_day  caffeine_intake  family_history  pet_owner  \
# ...
